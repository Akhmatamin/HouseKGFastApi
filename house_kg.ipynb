# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#1.Загрузить train.csv, вывести 10 строк.
data = pd.read_csv('house.csv')

# %%
data
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %% [markdown]
# 2.Посмотреть .info() и .shape.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
data.shape
# Out:
# (1460, 81)

# %%
#1
data.head(10)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
# 6   7          20       RL         75.0    10084   Pave   NaN      Reg
# 7   8          60       RL          NaN    10382   Pave   NaN      IR1
# 8   9          50       RM         51.0     6120   Pave   NaN      Reg
# 9  10         190       RL         50.0     7420   Pave   NaN      Reg
#
#   LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...

# %%
data.tail(10)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1450  1451          90       RL         60.0     9000   Pave   NaN      Reg
# 1451  1452          20       RL         78.0     9262   Pave   NaN      Reg
# 1452  1453         180       RM         35.0     3675   Pave   NaN      Reg
# 1453  1454          20       RL         90.0    17217   Pave   NaN      Reg
# 1454  1455          20       FV         62.0     7500   Pave  Pave      Reg
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# ...

# %%
#Вывести список колонок и их типы.
data.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %%
#4.Удалить все неиспользуемые признаки (оставить только нужные 7 +   ).
data=data[['GrLivArea','YearBuilt','GarageCars','TotalBsmtSF','FullBath','OverallQual','Neighborhood','SalePrice']]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   GrLivArea     1460 non-null   int64
#  1   YearBuilt     1460 non-null   int64
#  2   GarageCars    1460 non-null   int64
#  3   TotalBsmtSF   1460 non-null   int64
#  4   FullBath      1460 non-null   int64
#  5   OverallQual   1460 non-null   int64
#  6   Neighborhood  1460 non-null   object
#  7   SalePrice     1460 non-null   int64
# dtypes: int64(7), object(1)
# memory usage: 91.4+ KB

# %% [markdown]
# 5.Сохранить облегчённый датасет в отдельный CSV (data_clean.csv).

# %%
data.to_csv('house_clean.csv',index=False)

# %%
#6.Сколько уникальных районов (Neighborhood)?
data['Neighborhood'].nunique()
# Out:
# 25

# %%
#7.Средняя цена по району — топ 5 дорогих районов.
top=data.groupby('Neighborhood')['SalePrice'].mean().round()
top.sort_values(ascending=False).head(3)
# Out:
# Neighborhood
# NoRidge    335295.0
# NridgHt    316271.0
# StoneBr    310499.0
# Name: SalePrice, dtype: float64

# %%
data
# Out:
#       GrLivArea  YearBuilt  GarageCars  TotalBsmtSF  FullBath  OverallQual  \
# 0          1710       2003           2          856         2            7
# 1          1262       1976           2         1262         2            6
# 2          1786       2001           2          920         2            7
# 3          1717       1915           3          756         1            7
# 4          2198       2000           3         1145         2            8
# ...         ...        ...         ...          ...       ...          ...
# 1455       1647       1999           2          953         2            6
# 1456       2073       1978           2         1542         2            6
# 1457       2340       1941           1         1152         2            7
# 1458       1078       1950           1         1078         1            5
# 1459       1256       1965           1         1256         1            5
#
#      Neighborhood  SalePrice
# 0         CollgCr     208500
# ...

# %%
#8.Сколько домов было построено после 2000 года?
new_houses=(data['YearBuilt']>2000).sum()
print(f'Количество постороенных домов после 2000 года: {new_houses}')
# Out:
# Количество постороенных домов после 2000 года: 364

# %%
#9.Средняя жилая площадь (GrLivArea) по уровню качества (OverallQual).
data.groupby('OverallQual')['GrLivArea'].mean().round()
# Out:
# OverallQual
# 1      619.0
# 2      573.0
# 3     1119.0
# 4     1107.0
# 5     1251.0
# 6     1466.0
# 7     1704.0
# 8     1948.0
# 9     2078.0
# 10    3001.0
# Name: GrLivArea, dtype: float64

# %%
#10.Есть ли дома с нулевым подвалом? Посчитать долю таких домов.
no_basement=(data['TotalBsmtSF'] == 0).sum()
houses=(data['TotalBsmtSF'].shape[0])
print(f'Количество домов без подвала: {no_basement}')
print(f'Доля: {((no_basement*100)/houses).round(2)}%')
# Out:
# Количество домов без подвала: 37
# Доля: 2.53%

# %%
#11Группировка по GarageCars и средняя цена
data.groupby('GarageCars')['SalePrice'].mean().round()
# Out:
# GarageCars
# 0    103317.0
# 1    128117.0
# 2    183852.0
# 3    309636.0
# 4    192656.0
# Name: SalePrice, dtype: float64

# %%
#12.Сколько домов имеют 2+ ванных комнаты (FullBath)?
bathrooms=(data['FullBath']>2).sum()
print(f'Количество домов имеющих 2+ ванных комнат: {bathrooms}')
# Out:
# Количество домов имеющих 2+ ванных комнат: 33

# %%
#13.Район с наибольшим количеством домов.
data['Neighborhood'].value_counts().head(1)
# Out:
# Neighborhood
# NAmes    225
# Name: count, dtype: int64

# %%
#14.Корреляция GrLivArea, TotalBsmtSF, OverallQual, GarageCars с SalePrice.
new_data=data[['GrLivArea', 'TotalBsmtSF', 'OverallQual', 'GarageCars', 'SalePrice']]
new_data.corr()
# Out:
#              GrLivArea  TotalBsmtSF  OverallQual  GarageCars  SalePrice
# GrLivArea     1.000000     0.454868     0.593007    0.467247   0.708624
# TotalBsmtSF   0.454868     1.000000     0.537808    0.434585   0.613581
# OverallQual   0.593007     0.537808     1.000000    0.600671   0.790982
# GarageCars    0.467247     0.434585     0.600671    1.000000   0.640409
# SalePrice     0.708624     0.613581     0.790982    0.640409   1.000000

# %%
sns.heatmap(new_data.corr(), annot=True, cmap='coolwarm')
plt.show()

# %%
#15.Построить рейтинг районов по средней цене и сохранить в CSV.
rating_neighborhood = data.groupby('Neighborhood')['SalePrice'].mean().round().sort_values(ascending=False)
rating_neighborhood.to_csv('rating.csv')

# %% [markdown]
# Визуализация (Matplotlib & Seaborn)

# %%
#20.Построить гистограмму SalePrice + распределение (Seaborn distplot).
sns.histplot(data['SalePrice'], kde=True)
plt.show()

# %%
#21.Построить boxplot: OverallQual vs SalePrice.
sns.boxplot(x='OverallQual', y='SalePrice', data=data)
plt.show()

# %%
#22.Построить violinplot: Neighborhood vs SalePrice.
plt.figure(figsize=(16,6))
sns.violinplot(x='Neighborhood', y='SalePrice', data=data)
plt.xticks(rotation=45)
plt.show()

# %%
new_data2=data[['GrLivArea', 'YearBuilt','FullBath', 'OverallQual', 'GarageCars', 'SalePrice']]
new_data2.corr()
# Out:
#              GrLivArea  YearBuilt  FullBath  OverallQual  GarageCars  \
# GrLivArea     1.000000   0.199010  0.630012     0.593007    0.467247
# YearBuilt     0.199010   1.000000  0.468271     0.572323    0.537850
# FullBath      0.630012   0.468271  1.000000     0.550600    0.469672
# OverallQual   0.593007   0.572323  0.550600     1.000000    0.600671
# GarageCars    0.467247   0.537850  0.469672     0.600671    1.000000
# SalePrice     0.708624   0.522897  0.560664     0.790982    0.640409
#
#              SalePrice
# GrLivArea     0.708624
# YearBuilt     0.522897
# FullBath      0.560664
# OverallQual   0.790982
# GarageCars    0.640409
# SalePrice     1.000000

# %%
#23Построить heatmap корреляции между 6 числовыми признаками.
sns.heatmap(new_data2.corr(), annot=True, cmap='coolwarm')
plt.show()

# %%
#24.Построить scatterplot:
sns.scatterplot(x='GrLivArea', y='SalePrice',hue='GrLivArea',data=data)
plt.show()

# %%
sns.scatterplot(x='TotalBsmtSF', y='SalePrice',data=data)
plt.show()

# %%
sns.scatterplot(x='YearBuilt', y='SalePrice',data=data)
plt.show()

# %%
sns.barplot(x='GarageCars',y='SalePrice', data=data)
plt.show()

# %%
#26.Построить линейную регрессию regplot для GrLivArea vs SalePrice.
sns.regplot(x='GrLivArea', y='SalePrice', data=data)
plt.show()

# %%
#27.Построить pairplot по всем числовым признакам.
sns.pairplot(data.select_dtypes(include='number'))
plt.show()

# %% [markdown]
# ЭТАП 2: Предобработка данных

# %%
#28.Обработать пропущенные значения (если есть).
data.isnull().sum()
# Out:
# GrLivArea       0
# YearBuilt       0
# GarageCars      0
# TotalBsmtSF     0
# FullBath        0
# OverallQual     0
# Neighborhood    0
# SalePrice       0
# dtype: int64

# %%
#29.Преобразовать Neighborhood в числовой (one-hot или LabelEncoder).
data=pd.get_dummies(data, columns=['Neighborhood'], drop_first=True).astype(int)
data
# Out:
#       GrLivArea  YearBuilt  GarageCars  TotalBsmtSF  FullBath  OverallQual  \
# 0          1710       2003           2          856         2            7
# 1          1262       1976           2         1262         2            6
# 2          1786       2001           2          920         2            7
# 3          1717       1915           3          756         1            7
# 4          2198       2000           3         1145         2            8
# ...         ...        ...         ...          ...       ...          ...
# 1455       1647       1999           2          953         2            6
# 1456       2073       1978           2         1542         2            6
# 1457       2340       1941           1         1152         2            7
# 1458       1078       1950           1         1078         1            5
# 1459       1256       1965           1         1256         1            5
#
#       SalePrice  Neighborhood_Blueste  Neighborhood_BrDale  \
# ...

# %%
#30.Нормализовать числовые признаки (MinMaxScaler или StandardScaler).
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
dt = data.drop(columns=['SalePrice'])
scaled_data = scaler.fit_transform(dt)
scaled_data
# Out:
# array([[ 0.37033344,  1.05099379,  0.31172464, ..., -0.13199092,
#         -0.16347148, -0.08712888],
#        [-0.48251191,  0.15673371,  0.31172464, ..., -0.13199092,
#         -0.16347148, 11.47725023],
#        [ 0.51501256,  0.9847523 ,  0.31172464, ..., -0.13199092,
#         -0.16347148, -0.08712888],
#        ...,
#        [ 1.56964722, -1.00249232, -1.02685765, ..., -0.13199092,
#         -0.16347148, -0.08712888],
#        [-0.83278768, -0.70440562, -1.02685765, ..., -0.13199092,
#         -0.16347148, -0.08712888],
#        [-0.49393395, -0.20759447, -1.02685765, ..., -0.13199092,
#         -0.16347148, -0.08712888]])

# %%
#32.Разделить данные на X и y, где y = SalePrice.
x=scaled_data
y=data['SalePrice']

# %%
#33.Разбить данные на train/test (train_test_split, 80/20).
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
x_train.shape
# Out:
# (1168, 30)

# %% [markdown]
# ЭТАП 3: Обучение модели (Linear Regression)

# %%
#34.Построить модель LinearRegression() из sklearn.linear_model.
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import r2_score

r2_score(y_test, y_pred)
# Out:
# 0.8267380266474198

# %%
import joblib

joblib.dump(model, 'model.pkl')
joblib.dump(scaler, 'scaler.pkl')
# Out:
# ['scaler.pkl']

# %%
data.columns
# Out:
# Index(['GrLivArea', 'YearBuilt', 'GarageCars', 'TotalBsmtSF', 'FullBath',
#        'OverallQual', 'SalePrice', 'Neighborhood_Blueste',
#        'Neighborhood_BrDale', 'Neighborhood_BrkSide', 'Neighborhood_ClearCr',
#        'Neighborhood_CollgCr', 'Neighborhood_Crawfor', 'Neighborhood_Edwards',
#        'Neighborhood_Gilbert', 'Neighborhood_IDOTRR', 'Neighborhood_MeadowV',
#        'Neighborhood_Mitchel', 'Neighborhood_NAmes', 'Neighborhood_NPkVill',
#        'Neighborhood_NWAmes', 'Neighborhood_NoRidge', 'Neighborhood_NridgHt',
#        'Neighborhood_OldTown', 'Neighborhood_SWISU', 'Neighborhood_Sawyer',
#        'Neighborhood_SawyerW', 'Neighborhood_Somerst', 'Neighborhood_StoneBr',
#        'Neighborhood_Timber', 'Neighborhood_Veenker'],
#       dtype='object')

# %%
data
# Out:
#       GrLivArea  YearBuilt  GarageCars  TotalBsmtSF  FullBath  OverallQual  \
# 0          1710       2003           2          856         2            7
# 1          1262       1976           2         1262         2            6
# 2          1786       2001           2          920         2            7
# 3          1717       1915           3          756         1            7
# 4          2198       2000           3         1145         2            8
# ...         ...        ...         ...          ...       ...          ...
# 1455       1647       1999           2          953         2            6
# 1456       2073       1978           2         1542         2            6
# 1457       2340       1941           1         1152         2            7
# 1458       1078       1950           1         1078         1            5
# 1459       1256       1965           1         1256         1            5
#
#       SalePrice  Neighborhood_Blueste  Neighborhood_BrDale  \
# ...
